# %% [markdown]
# This is a verbal description - edited

# %% [markdown]
# <span style="color:darkblue"> Lecture 1: Introduction to Jupyter Notebooks </span>

# %% [markdown]
# <span style="color:red"> Lecture 1: Introduction to Jupyter Notebooks </span>

# %% [markdown]
# <span style="color:green"> Lecture 1: Introduction to Jupyter Notebooks </span>

# %% [markdown]
# <span <font size="5"> style="color:blue"> Lecture 1: Introduction to Jupyter Notebooks </span>

# %% [markdown]
# <span <img src="figures/project_flow.png" width="650"/>>

# %%
print("Hello World")
# Out:
#   Cell In[2], line 2
#     <span style="color:darkblue"> Lecture 1: Introduction to Jupyter Notebooks </span>
#     ^
# SyntaxError: invalid syntax
