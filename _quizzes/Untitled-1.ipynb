# %%
import numpy
import matplotlib.pyplot as matplot
import pandas
import os

#Question 1
os.chdir("C:/Users/Alyce/OneDrive - Emory/Data Science 151/practice_quiz/practice_quiz/quiz_data")
data_france = pandas.read_csv("C:/Users/Alyce/OneDrive - Emory/Data Science 151/practice_quiz/practice_quiz/quiz_data/france_emission.csv")

matplot.scatter(x = data_france["Year"], y = data_france["CO2_emission"])
matplot.xlabel("Year")
matplot.ylabel("CO2 Emissions")
matplot.title("Relationship between Time and CO2 Emissions in France")
matplot.show()

#Question 2
import random
first_word_choices = ["Introduction", "Guide", "Manual"]
selected_words = random.choices(first_word_choices, k = 2)

course_py = selected_words[0] + " for Python"
course_r = selected_words[1] + " for R"

print(course_py)
print(course_r)

keyword = "Guide"
if keyword in course_py and keyword in course_r:
    print("Keyword is in both strings")
elif keyword in course_py:
    print("Keyword is in course_py only")
elif keyword in course_r:
    print("Keyword is in course_r only")
else:
    print("Keyword is in neither string")
# Out:
# Introduction for Python
# Guide for R
# Keyword is in course_r only

# %%
#Question 3
index = 0
variables = ["displacement", "weight", "acceleration"]
features = pandas.read_csv("C:/Users/Alyce/OneDrive - Emory/Data Science 151/practice_quiz/practice_quiz/quiz_data/features.csv")

for x in variables:
    matplot.scatter(x = features[x], y = features["mpg"])
    index = index + 1
    variables = variables[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 9
#       7 matplot.scatter(x = features[x], y = features["mpg"])
#       8 index = index + 1
# ----> 9 variables = variables[1]
#
# IndexError: string index out of range

# %%
#Question 4
fruit1 = "apple"
fruit2 = "banana"
fruit_basket = ["orange", "apple", "grape", "kiwi"]

if fruit1 in fruit_basket:
    print("Apples are in the fruitbasket")
if fruit2 in fruit_basket:
    print("Bananas are in the fruit basket")
# Out:
# Apples are in the fruitbasket

# %%
#Question 5
x_vals = [3, -2, 5, 10]
y_vals = [4, 7, -1, 2]

x_vals = [x**2 for x in x_vals]
y_vals = [y**2 for y in y_vals]

x_vals = numpy.array(x_vals)
y_vals = numpy.array(y_vals)

distance_sqr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 6
#       3 y_vals = [4, 7, -1, 2]
#       4 index = 0
# ----> 6 x_vals = numpy.array[x_vals]
#       7 y_vals = numpy.array[y_vals]
#       9 x_vals = x_vals**2
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
